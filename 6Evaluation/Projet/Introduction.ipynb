# %% [markdown]
# Projet

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages (3.5.1)

# %%
from pymongo import MongoClient

client = MongoClient("mongo:27018")

# %%
print(client.database_names())

# %%
db_series = client.series
print(type(db_series))
# Out:
# <class 'pymongo.database.Database'>

# %%
collection_agora = db_series['agora_data']

# %%
import json
with open('./data/agora_repertoire_opendata.json', 'r') as f:
    categ = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-11-b66cb69fcc8e> in <module>
#       9     "nicknames" : ["Tom", "Tommy", "Thomas"],
#      10     "company" : "Peaky Blinders",
# ---> 11     "episodes" : [1,2,4,5,6]
#      12     })
#
# ~/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation)
#     665         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     666             document["_id"] = ObjectId()
# --> 667         with self._socket_for_writes() as sock_info:
#     668             return InsertOneResult(
#     669                 self._insert(sock_info, document,
#
# /usr/local/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, selector)
#     866     @contextlib.contextmanager
#     867     def _get_socket(self, selector):
# --> 868         server = self._get_topology().select_server(selector)
#     869         try:
#     870             with server.get_socket(self.__all_credentials) as sock_info:
#
# ~/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages/pymongo/topology.py in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# ~/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages/pymongo/topology.py in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: f1abe9ced324:27018: [Errno 111] Connection refused

# %% [markdown]
# 1) organisation qui dépence le plus

# %%
req = collection_agora.find({}).sort({"montantDepense" : -1}).limit(5)

# %% [markdown]
# 2) Récupération des secteurs qui bénéficie le plus de d'argent

# %%
req = collection_agora.find({},{listSecteursActivites, reponsablesPublics, montantDepense }).sort({montantDepense: -1})
